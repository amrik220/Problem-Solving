# %% [markdown]
# # Question 1

# %%
#!/bin/python3

import math
import os
import random
import re
import sys


#
# Complete the 'winner' function below.
#
# The function is expected to return a STRING.
# The function accepts following parameters:
#  1. STRING erica
#  2. STRING bob
#

def winner(erica, bob):
    marks = {'E': 1, 'M': 3, 'H': 5}
    ericas_score = 0
    bobs_score = 0
    for x in erica:
        ericas_score += marks.get(x, 0)
    
    for x in bob:
        bobs_score += marks.get(x, 0)
    
    if ericas_score > bobs_score:
        return 'Erica'
    elif bobs_score > ericas_score:
        return 'Bob'
    else:
        return 'Tie'

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    erica = input()

    bob = input()

    result = winner(erica, bob)

    fptr.write(result + '\n')

    fptr.close()

# %% [markdown]
# # Question 2

# %%
#!/bin/python3

import math
import os
import random
import re
import sys



import pandas as pd
#
# Complete the 'slowestKey' function below.
#
# The function is expected to return a CHARACTER.
# The function accepts 2D_INTEGER_ARRAY keyTimes as parameter.
#

def slowestKey(keyTimes):
    zore = [[-1, 0]]
    df0 = pd.DataFrame(data=zore)
    df =pd.DataFrame(data=keyTimes)

    result = pd.concat([df0,df])
    result['dif'] = result[1].diff()

    dif = result['dif'].max()

    return chr(int(result[result['dif'] == dif][0])+97)
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    keyTimes_rows = int(input().strip())
    keyTimes_columns = int(input().strip())

    keyTimes = []

    for _ in range(keyTimes_rows):
        keyTimes.append(list(map(int, input().rstrip().split())))

    result = slowestKey(keyTimes)

    fptr.write(str(result) + '\n')

    fptr.close()

# %% [markdown]
# # Question 3

# %%
#!/bin/python3

import sys
import os
from urllib.request import Request
from urllib.request import urlopen
from urllib.error import URLError
import json


# Complete the function below.
# Base query: https://jsonmock.hackerrank.com/api/stocks
import requests
from datetime import datetime

def getJsonData(page):
    api_url = 'https://jsonmock.hackerrank.com/api/stocks'
    api_url = api_url + '?page=' + str(page)
    response = requests.get(api_url)
    data = response.json()
    return data

def processAndPrint(date_first, date_last, data):
    list_data = []
    for x in data:
        current_date = datetime.strptime(x['date'], '%d-%B-%Y')
        #print(current_date, date_first, date_last)
        if current_date >= date_first and date_last >= current_date:
            print(x['date'], end = ' ')
            print(x['open'], end = ' ')
            print(x['close'])

def  openAndClosePrices(firstDate, lastDate):
    page_number = 1
    response = getJsonData(page_number)
    total_pages = int(response['total_pages'])
    date_first = datetime.strptime(firstDate, '%d-%B-%Y')
    date_last = datetime.strptime(lastDate, '%d-%B-%Y')

    processAndPrint(date_first, date_last, response['data'])
    for xpage in range(2, total_pages +1):
        response = getJsonData(xpage)
        processAndPrint(date_first, date_last, response['data'])

try:
    _firstDate = str(input())
except:
    _firstDate = None


try:
    _lastDate = str(input())
except:
    _lastDate = None

openAndClosePrices(_firstDate, _lastDate)

# %% [markdown]
# # Question 4

# %%
#!/bin/python3

import math
import os
import random
import re
import sys


#
# Complete the 'entryTime' function below.
#
# The function is expected to return an INTEGER.
# The function accepts following parameters:
#  1. STRING s
#  2. STRING keypad
#

def entryTime(s, keypad):
    # Write your code here
    s_array = [char for char in s]
    keypad_array = [char for char in keypad] 

    total = 0
    for i in range(1, len(s_array)):
        row_pre = keypad_array.index(s_array[i-1])//3
        col_pre = keypad_array.index(s_array[i-1])%3
        
        row_c = keypad_array.index(s_array[i])//3
        col_c = keypad_array.index(s_array[i])%3
        
        if abs(row_pre - row_c) ==2 or abs(col_pre - col_c) ==2:
            total = total+2
            print(2, abs(row_pre - row_c), abs(col_pre - col_c))
        elif abs(row_pre - row_c) !=0 or abs(col_pre - col_c) !=0:
            total =total+1
            print(1, abs(row_pre - row_c), abs(col_pre - col_c))
        else:
            print(0,abs(row_pre - row_c), abs(col_pre - col_c))

    return total
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    s = input()

    keypad = input()

    result = entryTime(s, keypad)

    fptr.write(str(result) + '\n')

    fptr.close()
